# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib notebook

# %%
def plot_canonical():
    
    x = np.linspace(-2*np.pi, 2*np.pi, 1000)
    y = x.copy()
    X, Y = np.meshgrid(x, y)
    
    Z1 = 1-np.sqrt(X**2 + Y**2)
    Z2 =1+ np.sqrt(X**2 + Y**2)
    
    fig = plt.figure()
    fig.set_dpi(150)
    ax = fig.add_subplot(111, projection='3d')
    
    ax.plot_surface(X, Y, Z1, color='green')
    ax.plot_surface(X, Y, Z2, color='green')
 

    plt.show()
    
    
    return
plot_canonical()
# Out:
# <img src="data:image/png;base64,..." width="959.8499999999999">

# %%
def plot_canonical_spherical():
    
    θ = np.linspace(0, 2*np.pi, 1000)
    z = np.linspace(-2, 2, 1000)
    
    Θ, Z = np.meshgrid(θ, z)
    
    X = (1+Z)**2*np.cos(Θ)
    Y = (1+Z)**2*np.sin(Θ)
    
    
    fig = plt.figure()
    fig.set_dpi(150)
    ax = fig.add_subplot(111, projection='3d')
    ax.plot_surface(X, Y, Z)
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_zlabel('z')
    
    plt.show()
    return

plot_canonical_spherical()
# Out:
# <img src="data:image/png;base64,..." width="959.8499999999999">
