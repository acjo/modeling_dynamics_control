# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import newton

# %% [markdown]
# # Exercise 6.1
# We sketch and justify the bifurcation diagram for the supercritical pitchfork bifurcation diagram $x' = \eta x - x^3$.

# %%
#get my embedding algorithm
def EmbeddingAlg(param_list, guess, F):
    X = []
    for param in param_list:
        try:
            # Solve for x_value making F(x_value, param) = 0.
            x_value = newton(F, guess, fprime=None, args=(param,), tol=1E-7, maxiter=50)
            # Record the solution and update guess for the next iteration.
            X.append(x_value)
            guess = x_value
        except RuntimeError:
            # If Newton's method fails, return a truncated list of parameters
            # with the corresponding x values.
            return param_list[:len(X)], X
    # Return the list of parameters and the corresponding x values.
    return param_list, X
#the differential equaiton
def F(x, η):
    return η*x-x**3

# Top curve shown in the bifurcation diagram
C1, X1 = EmbeddingAlg(np.linspace(5, -5, 200), np.sqrt(5), F)
# The bottom curve
C2, X2 = EmbeddingAlg(np.linspace(5, -5, 200), -np.sqrt(5), F)
#the zero curve
C3, X3 = EmbeddingAlg(np.linspace(5, -5, 200),  0, F)

#plot the figure
fig = plt.figure()
fig.set_dpi(100)
ax = fig.add_subplot(111)
ax.plot(C1, X1, 'k-')
ax.plot(C2, X2, 'k-')
ax.plot(C3, X3, 'k-')
ax.set_xlabel(r'$\eta$-axis')
ax.set_ylabel(r'$x$-axis')
ax.set_title(r'$\frac{dx}{dt} = \eta x - x^3$')

plt.show()

# %% [markdown]
# # Exercise 6.2
# We sketch the bifurcation diagram and the appropriate phase portraits as $\eta\in\mathbb{R}$ varies for $x' = \sin(x) + \eta$.

# %%
#the differential equaiton
def F(x, η):
    return np.sin(x) + η

#only one curve for this function
C1, X1 = EmbeddingAlg(np.linspace(-1, 1, 200), 0, F)
#plot the figure
fig = plt.figure()
fig.set_dpi(100)
ax = fig.add_subplot(111)
ax.plot(C1, X1, 'k-')
ax.set_xlabel(r'$\eta$-axis')
ax.set_ylabel(r'$x$-axis')
ax.set_title(r'$\frac{dx}{dt} = \sin(x)  +\eta$')

plt.show()



#define ode system
#we now plot our phase portrait
eta = np.sqrt(2)/2
def DF(x):
    
    return np.sin(x) + eta


x = np.linspace(0, 2*np.pi, 200)
y = DF(x)



#x = np.linspace(-1, 1, 200)
#x_prime = DF(x)
#y = np.zeros_like(x)
#mask = x_prime > 0
#get less than and equal than values
#greater_than = x[mask]
#greather_than_y = y[mask]
#less_than = x[~mask]
#less_than_y = y[~mask]

fig = plt.figure()
fig.set_dpi(300)
ax = fig.add_subplot(111)
ax.plot(x, y, 'k-')
ax.plot(-np.pi/4+2*np.pi, DF(-np.pi/4+2 *np.pi), 'ro', markersize=3)
ax.plot(-np.pi/4+3*np.pi/2, DF((-np.pi/4) + (3*np.pi/2)), 'ro', markersize=3)
ax.axhline(0, color='red', alpha=0.5)
ax.axvline(0, color='red', alpha=0.5)

ax.axis('square')
ax.set_title('Phase Portrait for the Given System')
ax.axis([0, 2*np.pi, -0.6, 2])

plt.arrow(0.5, 0, 0.25, 0,
          head_width = 0.2,
          width = 0.05)

plt.arrow(1.5, 0, 0.25, 0,
          head_width = 0.2,
          width = 0.05)

plt.arrow(2.5, 0, 0.25, 0,
          head_width = 0.2,
          width = 0.05)

plt.arrow(3.2, 0, 0.25, 0,
          head_width = 0.2,
          width = 0.05)

plt.arrow(4.6, 0, -0.25, 0,
          head_width = 0.2,
          width = 0.05)

plt.arrow(5.3, 0, -0.25, 0,
          head_width = 0.2,
          width = 0.05)

plt.arrow(5.5, 0, 0.25, 0,
          head_width = 0.2,
          width = 0.05)

plt.show()


print(np.arcsin(-np.sqrt(2)/2))
print(-np.pi/4)
# Out:
# -0.7853981633974484
# -0.7853981633974483

# %% [markdown]
# # Exercise 6.5
# we sketch the phase portraits for each case that occurs for the subcritical bifurcation diagram for $x' = \eta x + x^3$.

# %%
#the differential equaiton
def F(x, η):
    return η*x+x**3

# Top curve shown in the bifurcation diagram
C1, X1 = EmbeddingAlg(np.linspace(-5, 5, 200), np.sqrt(5), F)
# The bottom curve
C2, X2 = EmbeddingAlg(np.linspace(-5, 5, 200), -np.sqrt(5), F)
#the zero curve
C3, X3 = EmbeddingAlg(np.linspace(-5, 5, 200),  0, F)

#plot the figure
fig = plt.figure()
fig.set_dpi(100)
ax = fig.add_subplot(111)
ax.plot(C1, X1, 'k-')
ax.plot(C2, X2, 'k-')
ax.plot(C3, X3, 'k-')
ax.set_xlabel(r'$\eta$-axis')
ax.set_ylabel(r"$x'$-axis")
ax.set_title(r'$\frac{dx}{dt} = \eta x - x^3$')

plt.show()

# %% [markdown]
# # Exercise 6.6

# %%
#the differential equaiton
def F(x, η):
    return x*(1 - η*x)



# Top curve shown in the bifurcation diagram
C1, X1 = EmbeddingAlg(np.linspace(5, -5, 200), np.sqrt(5), F)
#the zero curve
C2, X2 = EmbeddingAlg(np.linspace(5, -5, 200),  0, F)
C3, X3 = EmbeddingAlg(np.linspace(-5, 5, 200),  -np.sqrt(5), F)



#plot the figure
fig = plt.figure()
fig.set_dpi(100)
ax = fig.add_subplot(111)
ax.plot(C1, X1, 'k-')
ax.plot(C2, X2, 'k-')
ax.plot(C3, X3, 'k-')
ax.set_xlabel(r'$\eta$-axis')
ax.set_ylabel(r"$x'$-axis")
ax.set_title(r'$\frac{dx}{dt} = x(1 - \eta x)$')

plt.show()

# %%
#the differential equaiton
def F(x):
    return x*(1 - (1/3)*x)


print(F(3.1))
# Out:
# -0.10333333333333297
